# %%
import pandas as pd
dataset = pd.read_csv('data.csv')
dataset
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# 5      AVqkIhwDv8e3D1O-lebb
# 6      AVqkIhwDv8e3D1O-lebb
# 7      AVqkIhwDv8e3D1O-lebb
# 8      AVqkIhwDv8e3D1O-lebb
# 9      AVqkIhwDv8e3D1O-lebb
# 10     AVqkIhwDv8e3D1O-lebb
# 11     AVqkIhwDv8e3D1O-lebb
# 12     AVqkIhwDv8e3D1O-lebb
# 13     AVqkIhwDv8e3D1O-lebb
# 14     AVqkIhwDv8e3D1O-lebb
# 15     AVqkIhwDv8e3D1O-lebb
# 16     AVqkIhwDv8e3D1O-lebb
# 17     AVqkIhwDv8e3D1O-lebb
# 18     AVqkIhwDv8e3D1O-lebb
# 19     AVqkIhwDv8e3D1O-lebb
# 20     AVqkIhwDv8e3D1O-lebb
# 21     AVqkIhwDv8e3D1O-lebb
# 22     AVqkIhwDv8e3D1O-lebb
# ...

# %%
dataset[dataset['reviews.rating'].isnull()]
# Out:
#                          id  \
# 2886   AVpfBEWcilAPnD_xTGb7
# 2887   AVpfBEWcilAPnD_xTGb7
# 2888   AVpfBEWcilAPnD_xTGb7
# 2889   AVpfBEWcilAPnD_xTGb7
# 2890   AVpfBEWcilAPnD_xTGb7
# 2891   AVpfBEWcilAPnD_xTGb7
# 2892   AVpfBEWcilAPnD_xTGb7
# 2893   AVpfBEWcilAPnD_xTGb7
# 2894   AVpfBEWcilAPnD_xTGb7
# 2895   AVpfBEWcilAPnD_xTGb7
# 2896   AVpfBEWcilAPnD_xTGb7
# 2897   AVpfBEWcilAPnD_xTGb7
# 2898   AVpfBEWcilAPnD_xTGb7
# 2899   AVpfBEWcilAPnD_xTGb7
# 2900   AVpfBEWcilAPnD_xTGb7
# 2901   AVpfBEWcilAPnD_xTGb7
# 2902   AVpfBEWcilAPnD_xTGb7
# 2903   AVpfBEWcilAPnD_xTGb7
# 2904   AVpfBEWcilAPnD_xTGb7
# 3691   AVpfwS_CLJeJML43DH5w
# 3692   AVpfwS_CLJeJML43DH5w
# 3693   AVpfwS_CLJeJML43DH5w
# 3694   AVpfwS_CLJeJML43DH5w
# 14727  AVpff7_VilAPnD_xc1E_
# 14728  AVpff7_VilAPnD_xc1E_
# 14729  AVpff7_VilAPnD_xc1E_
# 14731  AVpff7_VilAPnD_xc1E_
# 14732  AVpff7_VilAPnD_xc1E_
# 21226  AVpe7AsMilAPnD_xQ78G
# 21227  AVpe7AsMilAPnD_xQ78G
# 21228  AVpe7AsMilAPnD_xQ78G
# 21229  AVpe7AsMilAPnD_xQ78G
# ...

# %%
r1 = dataset.drop(29572)

# %%
r1[r1['reviews.rating'].isnull()]
# Out:
#                          id  \
# 2886   AVpfBEWcilAPnD_xTGb7
# 2887   AVpfBEWcilAPnD_xTGb7
# 2888   AVpfBEWcilAPnD_xTGb7
# 2889   AVpfBEWcilAPnD_xTGb7
# 2890   AVpfBEWcilAPnD_xTGb7
# 2891   AVpfBEWcilAPnD_xTGb7
# 2892   AVpfBEWcilAPnD_xTGb7
# 2893   AVpfBEWcilAPnD_xTGb7
# 2894   AVpfBEWcilAPnD_xTGb7
# 2895   AVpfBEWcilAPnD_xTGb7
# 2896   AVpfBEWcilAPnD_xTGb7
# 2897   AVpfBEWcilAPnD_xTGb7
# 2898   AVpfBEWcilAPnD_xTGb7
# 2899   AVpfBEWcilAPnD_xTGb7
# 2900   AVpfBEWcilAPnD_xTGb7
# 2901   AVpfBEWcilAPnD_xTGb7
# 2902   AVpfBEWcilAPnD_xTGb7
# 2903   AVpfBEWcilAPnD_xTGb7
# 2904   AVpfBEWcilAPnD_xTGb7
# 3691   AVpfwS_CLJeJML43DH5w
# 3692   AVpfwS_CLJeJML43DH5w
# 3693   AVpfwS_CLJeJML43DH5w
# 3694   AVpfwS_CLJeJML43DH5w
# 14727  AVpff7_VilAPnD_xc1E_
# 14728  AVpff7_VilAPnD_xc1E_
# 14729  AVpff7_VilAPnD_xc1E_
# 14731  AVpff7_VilAPnD_xc1E_
# 14732  AVpff7_VilAPnD_xc1E_
# 21226  AVpe7AsMilAPnD_xQ78G
# 21227  AVpe7AsMilAPnD_xQ78G
# 21228  AVpe7AsMilAPnD_xQ78G
# 21229  AVpe7AsMilAPnD_xQ78G
#
# ...

# %%
r2 = r1.drop(r1.index[21226:21230])

# %%
r2[r2['reviews.rating'].isnull()]
# Out:
#                          id  \
# 2886   AVpfBEWcilAPnD_xTGb7
# 2887   AVpfBEWcilAPnD_xTGb7
# 2888   AVpfBEWcilAPnD_xTGb7
# 2889   AVpfBEWcilAPnD_xTGb7
# 2890   AVpfBEWcilAPnD_xTGb7
# 2891   AVpfBEWcilAPnD_xTGb7
# 2892   AVpfBEWcilAPnD_xTGb7
# 2893   AVpfBEWcilAPnD_xTGb7
# 2894   AVpfBEWcilAPnD_xTGb7
# 2895   AVpfBEWcilAPnD_xTGb7
# 2896   AVpfBEWcilAPnD_xTGb7
# 2897   AVpfBEWcilAPnD_xTGb7
# 2898   AVpfBEWcilAPnD_xTGb7
# 2899   AVpfBEWcilAPnD_xTGb7
# 2900   AVpfBEWcilAPnD_xTGb7
# 2901   AVpfBEWcilAPnD_xTGb7
# 2902   AVpfBEWcilAPnD_xTGb7
# 2903   AVpfBEWcilAPnD_xTGb7
# 2904   AVpfBEWcilAPnD_xTGb7
# 3691   AVpfwS_CLJeJML43DH5w
# 3692   AVpfwS_CLJeJML43DH5w
# 3693   AVpfwS_CLJeJML43DH5w
# 3694   AVpfwS_CLJeJML43DH5w
# 14727  AVpff7_VilAPnD_xc1E_
# 14728  AVpff7_VilAPnD_xc1E_
# 14729  AVpff7_VilAPnD_xc1E_
# 14731  AVpff7_VilAPnD_xc1E_
# 14732  AVpff7_VilAPnD_xc1E_
#
#                                                     name       asins   brand  \
# ...

# %%
r3 = r2.drop(r2.index[14727:14733])

# %%
r3[r3['reviews.rating'].isnull()]
# Out:
#                         id                                               name  \
# 2886  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2887  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2888  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2889  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2890  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2891  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2892  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2893  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2894  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2895  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2896  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...

# %%
r4 = r3.drop(r3.index[3691:3695])

# %%
r4[r4['reviews.rating'].isnull()]
# Out:
#                         id                                               name  \
# 2886  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2887  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2888  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2889  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2890  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2891  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2892  AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# 2893  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2894  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2895  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2896  AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...

# %%
r5 = r4.drop(3111)
r5[r5['reviews.text'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, name, asins, brand, categories, keys, manufacturer, reviews.date, reviews.dateAdded, reviews.dateSeen, reviews.didPurchase, reviews.doRecommend, reviews.id, reviews.numHelpful, reviews.rating, reviews.sourceURLs, reviews.text, reviews.title, reviews.userCity, reviews.userProvince, reviews.username]
# Index: []
#
# [0 rows x 21 columns]

# %%
r6 = r5.drop(r5.index[2886:2905])
r6[r6['reviews.rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, name, asins, brand, categories, keys, manufacturer, reviews.date, reviews.dateAdded, reviews.dateSeen, reviews.didPurchase, reviews.doRecommend, reviews.id, reviews.numHelpful, reviews.rating, reviews.sourceURLs, reviews.text, reviews.title, reviews.userCity, reviews.userProvince, reviews.username]
# Index: []
#
# [0 rows x 21 columns]

# %%
r6.isnull().any()
# Out:
# id                      False
# name                     True
# asins                    True
# brand                   False
# categories              False
# keys                    False
# manufacturer            False
# reviews.date             True
# reviews.dateAdded        True
# reviews.dateSeen        False
# reviews.didPurchase      True
# reviews.doRecommend      True
# reviews.id               True
# reviews.numHelpful       True
# reviews.rating          False
# reviews.sourceURLs      False
# reviews.text            False
# reviews.title            True
# reviews.userCity         True
# reviews.userProvince     True
# reviews.username         True
# dtype: bool

# %%
rev_rat = r6[['reviews.rating', 'reviews.text']]

# %%
rev_rat['reviews.sentiment'] = 'negative'
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rev_rat
# Out:
#        reviews.rating                                       reviews.text  \
# 0                 5.0  This product so far has not disappointed. My c...
# 1                 5.0  great for beginner or experienced person. Boug...
# 2                 5.0  Inexpensive tablet for him to use and learn on...
# 3                 4.0  I've had my Fire HD 8 two weeks now and I love...
# 4                 5.0  I bought this for my grand daughter when she c...
# 5                 5.0  This amazon fire 8 inch tablet is the perfect ...
# 6                 4.0  Great for e-reading on the go, nice and light ...
# 7                 5.0  I gave this as a Christmas gift to my inlaws, ...
# 8                 5.0  Great as a device to read books. I like that i...
# 9                 5.0  I love ordering books and reading them with th...
# 10                4.0  Not easy for elderly users cease of ads that p...
# 11                5.0  Excellent product. Easy to use, large screen m...
# ...

# %%
rev_rat.loc[rev_rat['reviews.rating']>=4.0, 'reviews.sentiment'] = 'positive'
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rev_rat
# Out:
#        reviews.rating                                       reviews.text  \
# 0                 5.0  This product so far has not disappointed. My c...
# 1                 5.0  great for beginner or experienced person. Boug...
# 2                 5.0  Inexpensive tablet for him to use and learn on...
# 3                 4.0  I've had my Fire HD 8 two weeks now and I love...
# 4                 5.0  I bought this for my grand daughter when she c...
# 5                 5.0  This amazon fire 8 inch tablet is the perfect ...
# 6                 4.0  Great for e-reading on the go, nice and light ...
# 7                 5.0  I gave this as a Christmas gift to my inlaws, ...
# 8                 5.0  Great as a device to read books. I like that i...
# 9                 5.0  I love ordering books and reading them with th...
# 10                4.0  Not easy for elderly users cease of ads that p...
# 11                5.0  Excellent product. Easy to use, large screen m...
# ...

# %%
rev_rat.to_csv('final.csv')

# %%
test = pd.read_csv('review.csv')

# %%
len(rev_rat)
# Out:
# 34625

# %%
test_revrat = test[['reviews.rating', 'reviews.text']]

# %%
test_revrat
# Out:
#       reviews.rating                                       reviews.text
# 0                  3  I thought it would be as big as small paper bu...
# 1                  5  This kindle is light and easy to use especiall...
# 2                  4  Didnt know how much i'd use a kindle so went f...
# 3                  5  I am 100 happy with my purchase. I caught it o...
# 4                  5  Solid entry level Kindle. Great for kids. Gift...
# 5                  5  This make an excellent ebook reader. Don't exp...
# 6                  5  I ordered this for my daughter, as I have the ...
# 7                  4  I bought my Kindle about 2 months ago and the ...
# 8                  5  amazon kindle is always the best ebook, upgrad...
# 9                  5  It's beyond my expectation, and it can even sh...
# 10                 5  If you really want to have a good read on some...
# 11                 5  Love my kindle, makes reading at night so easy...
# ...

# %%
sent = test_revrat
sent['reviews.sentiment'] = 'negative'
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
sent
# Out:
#       reviews.rating                                       reviews.text  \
# 0                  3  I thought it would be as big as small paper bu...
# 1                  5  This kindle is light and easy to use especiall...
# 2                  4  Didnt know how much i'd use a kindle so went f...
# 3                  5  I am 100 happy with my purchase. I caught it o...
# 4                  5  Solid entry level Kindle. Great for kids. Gift...
# 5                  5  This make an excellent ebook reader. Don't exp...
# 6                  5  I ordered this for my daughter, as I have the ...
# 7                  4  I bought my Kindle about 2 months ago and the ...
# 8                  5  amazon kindle is always the best ebook, upgrad...
# 9                  5  It's beyond my expectation, and it can even sh...
# 10                 5  If you really want to have a good read on some...
# 11                 5  Love my kindle, makes reading at night so easy...
# ...

# %%
sent.loc[sent['reviews.rating']>=4, 'reviews.sentiment'] = 'positive'
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
sent
# Out:
#       reviews.rating                                       reviews.text  \
# 0                  3  I thought it would be as big as small paper bu...
# 1                  5  This kindle is light and easy to use especiall...
# 2                  4  Didnt know how much i'd use a kindle so went f...
# 3                  5  I am 100 happy with my purchase. I caught it o...
# 4                  5  Solid entry level Kindle. Great for kids. Gift...
# 5                  5  This make an excellent ebook reader. Don't exp...
# 6                  5  I ordered this for my daughter, as I have the ...
# 7                  4  I bought my Kindle about 2 months ago and the ...
# 8                  5  amazon kindle is always the best ebook, upgrad...
# 9                  5  It's beyond my expectation, and it can even sh...
# 10                 5  If you really want to have a good read on some...
# 11                 5  Love my kindle, makes reading at night so easy...
# ...

# %%
test_revrat
# Out:
#       reviews.rating                                       reviews.text  \
# 0                  3  I thought it would be as big as small paper bu...
# 1                  5  This kindle is light and easy to use especiall...
# 2                  4  Didnt know how much i'd use a kindle so went f...
# 3                  5  I am 100 happy with my purchase. I caught it o...
# 4                  5  Solid entry level Kindle. Great for kids. Gift...
# 5                  5  This make an excellent ebook reader. Don't exp...
# 6                  5  I ordered this for my daughter, as I have the ...
# 7                  4  I bought my Kindle about 2 months ago and the ...
# 8                  5  amazon kindle is always the best ebook, upgrad...
# 9                  5  It's beyond my expectation, and it can even sh...
# 10                 5  If you really want to have a good read on some...
# 11                 5  Love my kindle, makes reading at night so easy...
# ...

# %%
sent.to_csv('datatest_withsent.csv')

# %%
test_wosent = test[['reviews.rating', 'reviews.text']]
test_wosent
# Out:
#       reviews.rating                                       reviews.text
# 0                  3  I thought it would be as big as small paper bu...
# 1                  5  This kindle is light and easy to use especiall...
# 2                  4  Didnt know how much i'd use a kindle so went f...
# 3                  5  I am 100 happy with my purchase. I caught it o...
# 4                  5  Solid entry level Kindle. Great for kids. Gift...
# 5                  5  This make an excellent ebook reader. Don't exp...
# 6                  5  I ordered this for my daughter, as I have the ...
# 7                  4  I bought my Kindle about 2 months ago and the ...
# 8                  5  amazon kindle is always the best ebook, upgrad...
# 9                  5  It's beyond my expectation, and it can even sh...
# 10                 5  If you really want to have a good read on some...
# 11                 5  Love my kindle, makes reading at night so easy...
# ...

# %%
test_wosent.to_csv('datatest.csv')

# %%
train_to_test = rev_rat[['reviews.rating', 'reviews.text']]

# %%
train_to_test.to_csv('train_to_set.csv')

# %%
cut = train_to_test.drop(train_to_test.index[:27738])
cut
# Out:
#        reviews.rating                                       reviews.text
# 27772             5.0  It is so fun to ask alexa and get an answer or...
# 27773             5.0  Great buy my other blue tooth sound bar went o...
# 27774             5.0  Awesome we buy another one ASAP kelly was supe...
# 27775             5.0  We purchased the Alexa without reading much up...
# 27776             5.0  If only the echo could sync up to a wireless B...
# 27777             4.0  The sound is good, worth a try. The minus thin...
# 27778             5.0  She is great at controlling hue lights and har...
# 27779             5.0  At first I thought it would be just another on...
# 27780             4.0  Well built. Easy to set up. I was unsure about...
# 27781             5.0  great idea will recommend to everyone just can...
# 27782             5.0  Enjoyed my first Amazon Echo. Bought this unit...
# 27783             4.0  I don't use echo as much as I thought I would,...
# ...

# %%
cut.to_csv('train_data.csv')

# %%
df_row_merged = pd.concat([test_wosent, cut], ignore_index=True)

# %%
df_row_merged
# Out:
#        reviews.rating                                       reviews.text
# 0                 3.0  I thought it would be as big as small paper bu...
# 1                 5.0  This kindle is light and easy to use especiall...
# 2                 4.0  Didnt know how much i'd use a kindle so went f...
# 3                 5.0  I am 100 happy with my purchase. I caught it o...
# 4                 5.0  Solid entry level Kindle. Great for kids. Gift...
# 5                 5.0  This make an excellent ebook reader. Don't exp...
# 6                 5.0  I ordered this for my daughter, as I have the ...
# 7                 4.0  I bought my Kindle about 2 months ago and the ...
# 8                 5.0  amazon kindle is always the best ebook, upgrad...
# 9                 5.0  It's beyond my expectation, and it can even sh...
# 10                5.0  If you really want to have a good read on some...
# 11                5.0  Love my kindle, makes reading at night so easy...
# ...

# %%
df_row_merged.to_csv('data_test.csv')

# %%
cut2 = train_to_test.drop(train_to_test.index[27738:])
cut2
# Out:
#        reviews.rating                                       reviews.text
# 0                 5.0  This product so far has not disappointed. My c...
# 1                 5.0  great for beginner or experienced person. Boug...
# 2                 5.0  Inexpensive tablet for him to use and learn on...
# 3                 4.0  I've had my Fire HD 8 two weeks now and I love...
# 4                 5.0  I bought this for my grand daughter when she c...
# 5                 5.0  This amazon fire 8 inch tablet is the perfect ...
# 6                 4.0  Great for e-reading on the go, nice and light ...
# 7                 5.0  I gave this as a Christmas gift to my inlaws, ...
# 8                 5.0  Great as a device to read books. I like that i...
# 9                 5.0  I love ordering books and reading them with th...
# 10                4.0  Not easy for elderly users cease of ads that p...
# 11                5.0  Excellent product. Easy to use, large screen m...
# ...

# %%
cut2['reviews.sentiment'] = 'negative'

# %%
cut2.loc[cut2['reviews.rating']>=4, 'reviews.sentiment'] = 'positive'

# %%
cut2
# Out:
#        reviews.rating                                       reviews.text  \
# 0                 5.0  This product so far has not disappointed. My c...
# 1                 5.0  great for beginner or experienced person. Boug...
# 2                 5.0  Inexpensive tablet for him to use and learn on...
# 3                 4.0  I've had my Fire HD 8 two weeks now and I love...
# 4                 5.0  I bought this for my grand daughter when she c...
# 5                 5.0  This amazon fire 8 inch tablet is the perfect ...
# 6                 4.0  Great for e-reading on the go, nice and light ...
# 7                 5.0  I gave this as a Christmas gift to my inlaws, ...
# 8                 5.0  Great as a device to read books. I like that i...
# 9                 5.0  I love ordering books and reading them with th...
# 10                4.0  Not easy for elderly users cease of ads that p...
# 11                5.0  Excellent product. Easy to use, large screen m...
# ...

# %%
cut2.to_csv('data_train.csv')

# %%
df_row_merged['reviews.sentiment'] = 'negative'

# %%
df_row_merged.loc[df_row_merged['reviews.rating']>=4, 'reviews.sentiment'] = 'positive'

# %%
df_row_merged
# Out:
#        reviews.rating                                       reviews.text  \
# 0                 3.0  I thought it would be as big as small paper bu...
# 1                 5.0  This kindle is light and easy to use especiall...
# 2                 4.0  Didnt know how much i'd use a kindle so went f...
# 3                 5.0  I am 100 happy with my purchase. I caught it o...
# 4                 5.0  Solid entry level Kindle. Great for kids. Gift...
# 5                 5.0  This make an excellent ebook reader. Don't exp...
# 6                 5.0  I ordered this for my daughter, as I have the ...
# 7                 4.0  I bought my Kindle about 2 months ago and the ...
# 8                 5.0  amazon kindle is always the best ebook, upgrad...
# 9                 5.0  It's beyond my expectation, and it can even sh...
# 10                5.0  If you really want to have a good read on some...
# 11                5.0  Love my kindle, makes reading at night so easy...
# ...

# %%
df_row_merged.to_csv('data_test_with_sentiment.csv')
